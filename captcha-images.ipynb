# %%
import cv2 as cv
from PIL import Image
import os
import numpy as np
from keras.preprocessing.image import img_to_array

import warnings
warnings.filterwarnings('ignore')

# %%
x = []
y = []

for dname, _, fname in os.walk('samples/'):
    for fn in fname:
        path = os.path.join(dname, fn)
        image = cv.imread(path, cv.IMREAD_GRAYSCALE)
        image = cv.adaptiveThreshold(image, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 145, 0)
        kernel = np.ones((5, 5), np.uint8)
        image = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)
        kernel = np.ones((2, 2), np.uint8)
        image = cv.dilate(image, kernel, iterations=1)
        image = cv.GaussianBlur(image, (5, 5), 0)
        temp = [image[10:50, 30:50], image[10:50, 50:70], image[10:50, 70:90], image[10:50, 90:110], image[10:50, 110:130]]
        for i in range(5):
            x.append(img_to_array(Image.fromarray(temp[i])))
            y.append(path[len(path)-9:len(path)-4][i])

x = np.array(x)
y = np.array(y)

x.shape, y.shape
# Out:
# ((10700, 40, 20, 1), (10700,))

# %%
fig = plt.figure(figsize=(10, 7))

row, col = 3, 3
temp = './samples/ne325.png'

img1 = cv.imread(temp, cv.IMREAD_GRAYSCALE)
img2 = cv.adaptiveThreshold(img1, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 145, 0)
img3 = cv.adaptiveThreshold(img2, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 145, 0)
kernel = np.ones((5,5),np.uint8)
img4 = cv.morphologyEx(img3, cv.MORPH_CLOSE, kernel)
kernel = np.ones((2,2),np.uint8)
img5 = cv.dilate(img4, kernel, iterations = 1)
img6 = cv.GaussianBlur(img5, (5,5), 0)

fig.add_subplot(row, col, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Original', size=16)

fig.add_subplot(row, col, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Adaptive Threshold', size=16)

fig.add_subplot(row, col, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Adaptive Threshold', size=16)

fig.add_subplot(row, col, 4)
plt.imshow(img4)
plt.axis('off')
plt.title('Morphology', size=16)

fig.add_subplot(row, col, 5)
plt.imshow(img5)
plt.axis('off')
plt.title('Dilute', size=16)

fig.add_subplot(row, col, 6)
plt.imshow(img6)
plt.axis('off')
plt.title('Gaussian Blur', size=16)

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
x = x.astype('float32')
x/=255

le = LabelEncoder().fit_transform(y)
ohe = OneHotEncoder(sparse=False).fit_transform(le.reshape(len(le), 1))

x_train, x_test, y_train, y_test = train_test_split(x, ohe, test_size=0.2, random_state=35, shuffle=True)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((8560, 40, 20, 1), (8560, 19), (2140, 40, 20, 1), (2140, 19))

# %%
h, w = x.shape[1], x.shape[2] # input shape
c = 1 # color channel
node = ohe.shape[1] # last layer

# %%
import keras
import tensorflow as tf

from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential

# %%
model = Sequential([
    Input(shape=(h, w, c)),
    
    Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2), padding='same'),

    Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2), padding='same'),
    
    Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2), padding='same'),
    
    Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2, 2), padding='same'),
    
    Flatten(),
    Dropout(0.4),
    
    Dense(1500, activation='relu'),
    Dropout(0.2),
    
    Dense(node, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 20, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 20, 10, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 10, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 5, 16)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 10, 5, 32)         4640
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 3, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 5, 3, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 192)               0
#
#  dropout (Dropout)           (None, 192)               0
#
#  dense (Dense)               (None, 1500)              289500
#
#  dropout_1 (Dropout)         (None, 1500)              0
#
#  dense_1 (Dense)             (None, 19)                28519
#
# =================================================================
# Total params: 334,387
# Trainable params: 334,387
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam' ,
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = [
    tf.keras.callbacks.EarlyStopping(
        patience=5
    ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath='model.h5',
        verbose=1,
        monitor='val_loss',
        save_best_weight=True,
        model='auto'
    )
]

# %%
history = model.fit(
    x_train,
    y_train,
    validation_data=(x_test, y_test),
    batch_size=32,
    epochs=50,
    callbacks=early_stop,
    shuffle=True
)
# Out:
# Epoch 1/50
# 264/268 [============================>.] - ETA: 0s - loss: 1.7348 - accuracy: 0.4750
# Epoch 00001: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 1.7250 - accuracy: 0.4792 - val_loss: 0.8203 - val_accuracy: 0.7701
# Epoch 2/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.7740 - accuracy: 0.7810
# Epoch 00002: saving model to model.h5
# 268/268 [==============================] - 3s 10ms/step - loss: 0.7747 - accuracy: 0.7806 - val_loss: 0.5211 - val_accuracy: 0.8477
# Epoch 3/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.5884 - accuracy: 0.8312
# Epoch 00003: saving model to model.h5
# 268/268 [==============================] - 3s 10ms/step - loss: 0.5874 - accuracy: 0.8314 - val_loss: 0.3968 - val_accuracy: 0.8846
# Epoch 4/50
# 268/268 [==============================] - ETA: 0s - loss: 0.4944 - accuracy: 0.8520
# Epoch 00004: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.4944 - accuracy: 0.8520 - val_loss: 0.3689 - val_accuracy: 0.8907
# Epoch 5/50
# 267/268 [============================>.] - ETA: 0s - loss: 0.4325 - accuracy: 0.8663
# Epoch 00005: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.4320 - accuracy: 0.8665 - val_loss: 0.3463 - val_accuracy: 0.8981
# Epoch 6/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.3742 - accuracy: 0.8838
# Epoch 00006: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.3738 - accuracy: 0.8840 - val_loss: 0.3118 - val_accuracy: 0.9098
# Epoch 7/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.8883
# Epoch 00007: saving model to model.h5
# 268/268 [==============================] - 4s 13ms/step - loss: 0.3522 - accuracy: 0.8880 - val_loss: 0.2972 - val_accuracy: 0.9145
# Epoch 8/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.3229 - accuracy: 0.8961
# Epoch 00008: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.3247 - accuracy: 0.8953 - val_loss: 0.2745 - val_accuracy: 0.9173
# Epoch 9/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.2981 - accuracy: 0.9020
# Epoch 00009: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.2983 - accuracy: 0.9014 - val_loss: 0.2789 - val_accuracy: 0.9126
# Epoch 10/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.2768 - accuracy: 0.9082
# Epoch 00010: saving model to model.h5
# 268/268 [==============================] - 4s 14ms/step - loss: 0.2761 - accuracy: 0.9084 - val_loss: 0.2562 - val_accuracy: 0.9187
# Epoch 11/50
# 267/268 [============================>.] - ETA: 0s - loss: 0.2615 - accuracy: 0.9082
# Epoch 00011: saving model to model.h5
# 268/268 [==============================] - 4s 14ms/step - loss: 0.2616 - accuracy: 0.9082 - val_loss: 0.2388 - val_accuracy: 0.9262
# Epoch 12/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.2428 - accuracy: 0.9134
# Epoch 00012: saving model to model.h5
# 268/268 [==============================] - 4s 15ms/step - loss: 0.2423 - accuracy: 0.9136 - val_loss: 0.2148 - val_accuracy: 0.9346
# Epoch 13/50
# 267/268 [============================>.] - ETA: 0s - loss: 0.2235 - accuracy: 0.9202
# Epoch 00013: saving model to model.h5
# 268/268 [==============================] - 4s 14ms/step - loss: 0.2242 - accuracy: 0.9200 - val_loss: 0.2136 - val_accuracy: 0.9346
# Epoch 14/50
# 267/268 [============================>.] - ETA: 0s - loss: 0.2267 - accuracy: 0.9205
# Epoch 00014: saving model to model.h5
# 268/268 [==============================] - 4s 13ms/step - loss: 0.2272 - accuracy: 0.9204 - val_loss: 0.2028 - val_accuracy: 0.9374
# Epoch 15/50
# 265/268 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9244
# Epoch 00015: saving model to model.h5
# 268/268 [==============================] - 4s 14ms/step - loss: 0.2049 - accuracy: 0.9245 - val_loss: 0.2029 - val_accuracy: 0.9379
# Epoch 16/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9261
# Epoch 00016: saving model to model.h5
# 268/268 [==============================] - 4s 13ms/step - loss: 0.2042 - accuracy: 0.9261 - val_loss: 0.2033 - val_accuracy: 0.9360
# Epoch 17/50
# 263/268 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9313
# Epoch 00017: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1908 - accuracy: 0.9307 - val_loss: 0.1954 - val_accuracy: 0.9435
# Epoch 18/50
# 267/268 [============================>.] - ETA: 0s - loss: 0.1782 - accuracy: 0.9353
# Epoch 00018: saving model to model.h5
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1786 - accuracy: 0.9350 - val_loss: 0.1899 - val_accuracy: 0.9481
# Epoch 19/50
# 265/268 [============================>.] - ETA: 0s - loss: 0.1743 - accuracy: 0.9364
# Epoch 00019: saving model to model.h5
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1743 - accuracy: 0.9363 - val_loss: 0.1905 - val_accuracy: 0.9430
# Epoch 20/50
# 265/268 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9351
# Epoch 00020: saving model to model.h5
# 268/268 [==============================] - 4s 14ms/step - loss: 0.1724 - accuracy: 0.9354 - val_loss: 0.1820 - val_accuracy: 0.9472
# Epoch 21/50
# 268/268 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9429
# Epoch 00021: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1599 - accuracy: 0.9429 - val_loss: 0.1684 - val_accuracy: 0.9533
# Epoch 22/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.1684 - accuracy: 0.9375
# Epoch 00022: saving model to model.h5
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1687 - accuracy: 0.9373 - val_loss: 0.1722 - val_accuracy: 0.9453
# Epoch 23/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.1535 - accuracy: 0.9444
# Epoch 00023: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.1534 - accuracy: 0.9445 - val_loss: 0.1787 - val_accuracy: 0.9523
# Epoch 24/50
# 268/268 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9424
# Epoch 00024: saving model to model.h5
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1573 - accuracy: 0.9424 - val_loss: 0.1609 - val_accuracy: 0.9556
# Epoch 25/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9491
# Epoch 00025: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1418 - accuracy: 0.9489 - val_loss: 0.1792 - val_accuracy: 0.9519
# Epoch 26/50
# 265/268 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9491
# Epoch 00026: saving model to model.h5
# 268/268 [==============================] - 3s 11ms/step - loss: 0.1380 - accuracy: 0.9488 - val_loss: 0.1640 - val_accuracy: 0.9519
# Epoch 27/50
# 265/268 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9496
# Epoch 00027: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1367 - accuracy: 0.9499 - val_loss: 0.1716 - val_accuracy: 0.9551
# Epoch 28/50
# 266/268 [============================>.] - ETA: 0s - loss: 0.1330 - accuracy: 0.9515
# Epoch 00028: saving model to model.h5
# 268/268 [==============================] - 3s 12ms/step - loss: 0.1326 - accuracy: 0.9515 - val_loss: 0.1661 - val_accuracy: 0.9542
# Epoch 29/50
# 264/268 [============================>.] - ETA: 0s - loss: 0.1314 - accuracy: 0.9493
# Epoch 00029: saving model to model.h5
# 268/268 [==============================] - 3s 13ms/step - loss: 0.1320 - accuracy: 0.9494 - val_loss: 0.1823 - val_accuracy: 0.9551

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], '-x',label='Loss')
plt.plot(history.history['val_loss'], '-o',label='Validation Loss')
plt.legend()
plt.xlabel('Epochs', size=16)
plt.ylabel('Loss', size=16)
plt.title('Plot of Loss and Validation Loss', size=16)
plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], '-x', label='Accuracy')
plt.plot(history.history['val_accuracy'], '-o', label='Validation Accuracy')
plt.legend()
plt.xlabel('Epochs', size=16)
plt.ylabel('Accuracy', size=16)
plt.title('Plot of Accuracy and Validation Loss', size=16)
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9551
# [0.1822603940963745, 0.9551401734352112]

# %%
info = {le[i] : y[i] for i in range(len(y))}

def prediction (img_path) :
    
    img = cv.imread(img_path, cv.IMREAD_GRAYSCALE)
    
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.show()
    
    image = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 145, 0)
    image = cv.adaptiveThreshold(image, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 145, 0)
    kernel = np.ones((5,5),np.uint8)
    image = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)
    kernel = np.ones((2,2),np.uint8)
    image = cv.dilate(image, kernel, iterations = 1)
    image = cv.GaussianBlur(image, (5,5), 0)
    
    
    x = [image[10:50, 30:50], image[10:50, 50:70], image[10:50, 70:90],
                  image[10:50, 90:110], image[10:50, 110:130]]
    
    X_pred = []
    for i in range(5) :
        X_pred.append(img_to_array(Image.fromarray(x[i])))
    
    X_pred = np.array(X_pred)
    X_pred/= 255.0
    
    y_pred = model.predict(X_pred)
    y_pred = np.argmax(y_pred, axis = 1)
    
    print('Prediction: ', end='')
    for res in y_pred :
        print(info[res], end='')
        
    print('\nActual:    ', img_path[len(img_path)-9:len(img_path)-4])

# %%
import glob

img = glob.glob('./samples/*.png')

# %%
prediction(img[629])
# Out:
# Prediction: e84m2
# Actual:     e84n2
